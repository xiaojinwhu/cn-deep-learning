# %% [markdown]
# # 语言翻译
#
# 在此项目中，你将了解神经网络机器翻译这一领域。你将用由英语和法语语句组成的数据集，训练一个序列到序列模型（sequence to sequence model），该模型能够将新的英语句子翻译成法语。
#
# ## 获取数据
#
# 因为将整个英语语言内容翻译成法语需要大量训练时间，所以我们提供了一小部分的英语语料库。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## 探索数据
#
# 研究 view_sentence_range，查看并熟悉该数据的不同部分。

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## 实现预处理函数
#
# ### 文本到单词 id
#
# 和之前的 RNN 一样，你必须首先将文本转换为数字，这样计算机才能读懂。在函数 `text_to_ids()` 中，你需要将单词中的 `source_text` 和 `target_text` 转为 id。但是，你需要在 `target_text` 中每个句子的末尾，添加 `<EOS>` 单词 id。这样可以帮助神经网络预测句子应该在什么地方结束。
#
#
# 你可以通过以下代码获取  `<EOS> ` 单词ID：
#
# ```python
# target_vocab_to_int['<EOS>']
# ```
#
# 你可以使用 `source_vocab_to_int` 和 `target_vocab_to_int` 获得其他单词 id。

# %%
source_text_set = [word for line in source_text.split('\n') for word in line.split()]
print(source_text_set[:20])
# Out:
# ['new', 'jersey', 'is', 'sometimes', 'quiet', 'during', 'autumn', ',', 'and', 'it', 'is', 'snowy', 'in', 'april', '.', 'the', 'united', 'states', 'is', 'usually']

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    #  
    eos = target_vocab_to_int['<EOS>']
    
    # source_text_set = set([word for line in source_text.split('\n') for word in line.split()])  # 不用split(' ')， 不要扁平化！！！
    source_id_text = [[source_vocab_to_int[word] for word in line.split()] for line in source_text.split('\n')]
    print(source_id_text)
    
    # target_line = [line + ' <EOS>' for line in target_text.split('\n')]
    
    target_id_text = [[target_vocab_to_int[word] for word in line.split()] + [eos] for line in target_text.split('\n')]
    print(target_id_text)
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# [[8, 7, 32, 27, 18, 28, 4, 11, 9, 20, 32, 19, 17, 21, 12], [30, 26, 22, 32, 6, 10, 28, 29, 11, 9, 20, 32, 6, 14, 17, 23, 12], [24, 32, 6, 18, 28, 5, 11, 9, 20, 32, 6, 15, 17, 16, 12], [30, 26, 22, 32, 27, 13, 28, 16, 11, 9, 20, 32, 31, 17, 25, 12]]
# [[6, 5, 27, 16, 4, 7, 29, 13, 9, 17, 14, 27, 24, 22, 10, 12, 1], [32, 20, 27, 15, 26, 22, 33, 9, 17, 14, 19, 18, 22, 11, 12, 1], [23, 27, 15, 4, 22, 30, 9, 17, 14, 27, 15, 8, 22, 25, 12, 1], [32, 20, 27, 16, 28, 22, 25, 9, 17, 14, 21, 26, 22, 31, 12, 1]]
# Tests Passed

# %% [markdown]
# ### 预处理所有数据并保存
#
# 运行以下代码单元，预处理所有数据，并保存到文件中。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，可以从这里继续。预处理的数据已保存到磁盘上。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### 检查 TensorFlow 版本，确认可访问 GPU
#
# 这一检查步骤，可以确保你使用的是正确版本的 TensorFlow，并且能够访问 GPU。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# C:\ProgramData\Anaconda3\envs\dlndpy35\lib\site-packages\ipykernel\__main__.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## 构建神经网络
#
# 你将通过实现以下函数，构建出要构建一个序列到序列模型所需的组件：
#
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### 输入
#
# 实现 `model_inputs()` 函数，为神经网络创建 TF 占位符。该函数应该创建以下占位符：
#
# - 名为 “input” 的输入文本占位符，并使用 TF Placeholder 名称参数（等级（Rank）为 2）。
# - 目标占位符（等级为 2）。
# - 学习速率占位符（等级为 0）。
# - 名为 “keep_prob” 的保留率占位符，并使用 TF Placeholder 名称参数（等级为 0）。
#
# 在以下元祖（tuple）中返回占位符：（输入、目标、学习速率、保留率）

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    input = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    return input, targets, learning_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 处理解码输入
#
# 使用 TensorFlow 实现 `process_decoding_input`，以便删掉 `target_data` 中每个批次的最后一个单词 ID，并将 GO ID 放到每个批次的开头。

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    # tf.strided_slice(data, begin, end, stride)
    end = tf.strided_slice(target_data, [0,0], [batch_size,-1], [1,1])
    decoder_input = tf.concat([tf.fill([batch_size,1], target_vocab_to_int['<GO>']), end], 1)  # 注意
    return decoder_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### 编码
#
# 实现 `encoding_layer()`，以使用 [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn) 创建编码器 RNN 层级。

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
    enc_cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    _, enc_state = tf.nn.dynamic_rnn(enc_cell, rnn_inputs, dtype=tf.float32)
    return enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 训练
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建训练分对数（training logits）。将 `output_fn` 应用到 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 输出上。

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    dec_fn_train = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    outputs_train, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, dec_fn_train, dec_embed_input, sequence_length, scope=decoding_scope)
    logits_train = output_fn(outputs_train)
    logits = tf.nn.dropout(logits_train, keep_prob)
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 推论
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建推论分对数（inference logits）。

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    dec_fn_infer = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, 
                                                                  encoder_state, 
                                                                  dec_embeddings, 
                                                                  start_of_sequence_id, 
                                                                  end_of_sequence_id, 
                                                                  maximum_length, 
                                                                  vocab_size)
    dropouted = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
    logits_infer, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dropouted, dec_fn_infer, 
                                                                sequence_length=maximum_length, 
                                                                scope=decoding_scope)
    return logits_infer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建解码层级
#
# 实现 `decoding_layer()` 以创建解码器 RNN 层级。
#
# - 使用 `rnn_size` 和 `num_layers` 创建解码 RNN 单元。
# - 使用 [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) 创建输出函数，将输入，也就是分对数转换为类分对数（class logits）。
# - 使用 `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` 函数获取训练分对数。
# - 使用 `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` 函数获取推论分对数。
#
# 注意：你将需要使用 [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 在训练和推论分对数间分享变量。

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dropout = tf.contrib.rnn.DropoutWrapper(lstm, keep_prob)
    dec_cell = tf.contrib.rnn.MultiRNNCell([dropout] * num_layers)
    
    max_target_sentence_length = max([len(sentence) for sentence in source_int_text])
    
    with tf.variable_scope('decoding_layer') as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
    
    with tf.variable_scope('decoding_layer') as decoding_scope:
        logits_train = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                                            sequence_length, decoding_scope, output_fn, keep_prob)
    
    with tf.variable_scope('decoding_layer', reuse=True) as decoding_scope:
        logits_infer = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, 
                                            target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'], 
                                            max_target_sentence_length, 
                                            vocab_size, decoding_scope, output_fn, keep_prob)
    
    return logits_train, logits_infer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建神经网络
#
# 应用你在上方实现的函数，以：
#
# - 向编码器的输入数据应用嵌入。
# - 使用 `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)` 编码输入。
# - 使用 `process_decoding_input(target_data, target_vocab_to_int, batch_size)` 函数处理目标数据。
# - 向解码器的目标数据应用嵌入。
# - 使用 `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)` 解码编码的输入数据。

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    enc_state = encoding_layer(enc_embed_input, rnn_size, num_layers, keep_prob)
    
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    dec_embeddings = tf.Variable(tf.truncated_normal([target_vocab_size, dec_embedding_size], stddev=0.01))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    logits_train, logits_infer = decoding_layer(dec_embed_input, dec_embeddings, 
                                                enc_state, target_vocab_size, 
                                                sequence_length, rnn_size, num_layers, 
                                                target_vocab_to_int, keep_prob)
    
    return logits_train, logits_infer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络
#
# ### 超参数
#
# 调试以下参数：
#
# - 将 `epochs` 设为 epoch 次数。
# - 将 `batch_size` 设为批次大小。
# - 将 `rnn_size` 设为 RNN 的大小。
# - 将 `num_layers` 设为层级数量。
# - 将 `encoding_embedding_size` 设为编码器嵌入大小。
# - 将 `decoding_embedding_size` 设为解码器嵌入大小
# - 将 `learning_rate` 设为训练速率。
# - 将 `keep_probability` 设为丢弃保留率（Dropout keep probability）。

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 3
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.08

# %% [markdown]
# ### 构建图表
#
# 使用你实现的神经网络构建图表。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### 训练
#
# 利用预处理的数据训练神经网络。如果很难获得低损失值，请访问我们的论坛，看看其他人是否遇到了相同的问题。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/538 - Train Accuracy:  0.249, Validation Accuracy:  0.329, Loss:  5.881
# Epoch   0 Batch    1/538 - Train Accuracy:  0.224, Validation Accuracy:  0.305, Loss:  5.787
# Epoch   0 Batch    2/538 - Train Accuracy:  0.107, Validation Accuracy:  0.185, Loss:  7.347
# Epoch   0 Batch    3/538 - Train Accuracy:  0.104, Validation Accuracy:  0.188, Loss: 12.497
# Epoch   0 Batch    4/538 - Train Accuracy:  0.233, Validation Accuracy:  0.311, Loss:  8.140
# Epoch   0 Batch    5/538 - Train Accuracy:  0.266, Validation Accuracy:  0.319, Loss:  6.723
# Epoch   0 Batch    6/538 - Train Accuracy:  0.148, Validation Accuracy:  0.187, Loss:  6.080
# Epoch   0 Batch    7/538 - Train Accuracy:  0.291, Validation Accuracy:  0.358, Loss:  5.997
# Epoch   0 Batch    8/538 - Train Accuracy:  0.277, Validation Accuracy:  0.344, Loss:  5.921
# Epoch   0 Batch    9/538 - Train Accuracy:  0.277, Validation Accuracy:  0.344, Loss:  5.875
# Epoch   0 Batch   10/538 - Train Accuracy:  0.258, Validation Accuracy:  0.345, Loss:  5.871
# Epoch   0 Batch   11/538 - Train Accuracy:  0.281, Validation Accuracy:  0.352, Loss:  5.861
# Epoch   0 Batch   12/538 - Train Accuracy:  0.277, Validation Accuracy:  0.356, Loss:  5.850
# Epoch   0 Batch   13/538 - Train Accuracy:  0.322, Validation Accuracy:  0.356, Loss:  5.852
# Epoch   0 Batch   14/538 - Train Accuracy:  0.279, Validation Accuracy:  0.352, Loss:  5.821
# Epoch   0 Batch   15/538 - Train Accuracy:  0.324, Validation Accuracy:  0.351, Loss:  5.777
# Epoch   0 Batch   16/538 - Train Accuracy:  0.308, Validation Accuracy:  0.350, Loss:  5.765
# Epoch   0 Batch   17/538 - Train Accuracy:  0.290, Validation Accuracy:  0.352, Loss:  5.784
# Epoch   0 Batch   18/538 - Train Accuracy:  0.270, Validation Accuracy:  0.348, Loss:  5.772
# Epoch   0 Batch   19/538 - Train Accuracy:  0.300, Validation Accuracy:  0.371, Loss:  5.756
# Epoch   0 Batch   20/538 - Train Accuracy:  0.331, Validation Accuracy:  0.373, Loss:  5.746
# Epoch   0 Batch   21/538 - Train Accuracy:  0.263, Validation Accuracy:  0.375, Loss:  5.770
# Epoch   0 Batch   22/538 - Train Accuracy:  0.307, Validation Accuracy:  0.373, Loss:  5.737
# Epoch   0 Batch   23/538 - Train Accuracy:  0.312, Validation Accuracy:  0.373, Loss:  5.723
# Epoch   0 Batch   24/538 - Train Accuracy:  0.328, Validation Accuracy:  0.369, Loss:  5.718
# Epoch   0 Batch   25/538 - Train Accuracy:  0.311, Validation Accuracy:  0.374, Loss:  5.741
# Epoch   0 Batch   26/538 - Train Accuracy:  0.311, Validation Accuracy:  0.377, Loss:  5.707
# Epoch   0 Batch   27/538 - Train Accuracy:  0.318, Validation Accuracy:  0.381, Loss:  5.731
# Epoch   0 Batch   28/538 - Train Accuracy:  0.381, Validation Accuracy:  0.381, Loss:  5.718
# Epoch   0 Batch   29/538 - Train Accuracy:  0.342, Validation Accuracy:  0.377, Loss:  5.715
# Epoch   0 Batch   30/538 - Train Accuracy:  0.318, Validation Accuracy:  0.384, Loss:  5.712
# Epoch   0 Batch   31/538 - Train Accuracy:  0.347, Validation Accuracy:  0.381, Loss:  5.681
# Epoch   0 Batch   32/538 - Train Accuracy:  0.269, Validation Accuracy:  0.315, Loss:  5.719
# Epoch   0 Batch   33/538 - Train Accuracy:  0.339, Validation Accuracy:  0.376, Loss:  5.674
# Epoch   0 Batch   34/538 - Train Accuracy:  0.321, Validation Accuracy:  0.380, Loss:  5.693
# Epoch   0 Batch   35/538 - Train Accuracy:  0.287, Validation Accuracy:  0.368, Loss:  5.690
# Epoch   0 Batch   36/538 - Train Accuracy:  0.330, Validation Accuracy:  0.369, Loss:  5.666
# Epoch   0 Batch   37/538 - Train Accuracy:  0.252, Validation Accuracy:  0.317, Loss:  5.685
# Epoch   0 Batch   38/538 - Train Accuracy:  0.267, Validation Accuracy:  0.337, Loss:  5.686
# Epoch   0 Batch   39/538 - Train Accuracy:  0.308, Validation Accuracy:  0.378, Loss:  5.690
# Epoch   0 Batch   40/538 - Train Accuracy:  0.378, Validation Accuracy:  0.384, Loss:  5.640
# Epoch   0 Batch   41/538 - Train Accuracy:  0.314, Validation Accuracy:  0.378, Loss:  5.669
# Epoch   0 Batch   42/538 - Train Accuracy:  0.283, Validation Accuracy:  0.346, Loss:  5.677
# Epoch   0 Batch   43/538 - Train Accuracy:  0.286, Validation Accuracy:  0.346, Loss:  5.667
# Epoch   0 Batch   44/538 - Train Accuracy:  0.312, Validation Accuracy:  0.381, Loss:  5.689
# Epoch   0 Batch   45/538 - Train Accuracy:  0.353, Validation Accuracy:  0.388, Loss:  5.653
# Epoch   0 Batch   46/538 - Train Accuracy:  0.328, Validation Accuracy:  0.392, Loss:  5.645
# Epoch   0 Batch   47/538 - Train Accuracy:  0.342, Validation Accuracy:  0.370, Loss:  5.622
# Epoch   0 Batch   48/538 - Train Accuracy:  0.337, Validation Accuracy:  0.365, Loss:  5.632
# Epoch   0 Batch   49/538 - Train Accuracy:  0.299, Validation Accuracy:  0.375, Loss:  5.639
# Epoch   0 Batch   50/538 - Train Accuracy:  0.326, Validation Accuracy:  0.385, Loss:  5.637
# Epoch   0 Batch   51/538 - Train Accuracy:  0.238, Validation Accuracy:  0.347, Loss:  5.690
# Epoch   0 Batch   52/538 - Train Accuracy:  0.282, Validation Accuracy:  0.335, Loss:  5.666
# Epoch   0 Batch   53/538 - Train Accuracy:  0.343, Validation Accuracy:  0.347, Loss:  5.636
# Epoch   0 Batch   54/538 - Train Accuracy:  0.286, Validation Accuracy:  0.343, Loss:  5.667
# Epoch   0 Batch   55/538 - Train Accuracy:  0.294, Validation Accuracy:  0.357, Loss:  5.651
# Epoch   0 Batch   56/538 - Train Accuracy:  0.306, Validation Accuracy:  0.346, Loss:  5.642
# Epoch   0 Batch   57/538 - Train Accuracy:  0.249, Validation Accuracy:  0.331, Loss:  5.661
# Epoch   0 Batch   58/538 - Train Accuracy:  0.277, Validation Accuracy:  0.351, Loss:  5.621
# Epoch   0 Batch   59/538 - Train Accuracy:  0.265, Validation Accuracy:  0.351, Loss:  5.665
# Epoch   0 Batch   60/538 - Train Accuracy:  0.281, Validation Accuracy:  0.347, Loss:  5.627
# Epoch   0 Batch   61/538 - Train Accuracy:  0.288, Validation Accuracy:  0.350, Loss:  5.636
# Epoch   0 Batch   62/538 - Train Accuracy:  0.342, Validation Accuracy:  0.371, Loss:  5.640
# Epoch   0 Batch   63/538 - Train Accuracy:  0.286, Validation Accuracy:  0.309, Loss:  5.626
# Epoch   0 Batch   64/538 - Train Accuracy:  0.264, Validation Accuracy:  0.292, Loss:  5.609
# Epoch   0 Batch   65/538 - Train Accuracy:  0.245, Validation Accuracy:  0.310, Loss:  5.646
# Epoch   0 Batch   66/538 - Train Accuracy:  0.347, Validation Accuracy:  0.373, Loss:  5.635
# Epoch   0 Batch   67/538 - Train Accuracy:  0.325, Validation Accuracy:  0.379, Loss:  5.627
# Epoch   0 Batch   68/538 - Train Accuracy:  0.298, Validation Accuracy:  0.340, Loss:  5.618
# Epoch   0 Batch   69/538 - Train Accuracy:  0.282, Validation Accuracy:  0.350, Loss:  5.612
# Epoch   0 Batch   70/538 - Train Accuracy:  0.339, Validation Accuracy:  0.367, Loss:  5.603
# Epoch   0 Batch   71/538 - Train Accuracy:  0.295, Validation Accuracy:  0.362, Loss:  5.632
# Epoch   0 Batch   72/538 - Train Accuracy:  0.307, Validation Accuracy:  0.346, Loss:  5.618
# Epoch   0 Batch   73/538 - Train Accuracy:  0.256, Validation Accuracy:  0.324, Loss:  5.662
# Epoch   0 Batch   74/538 - Train Accuracy:  0.302, Validation Accuracy:  0.335, Loss:  5.604
# Epoch   0 Batch   75/538 - Train Accuracy:  0.313, Validation Accuracy:  0.349, Loss:  5.628
# Epoch   0 Batch   76/538 - Train Accuracy:  0.274, Validation Accuracy:  0.355, Loss:  5.643
# Epoch   0 Batch   77/538 - Train Accuracy:  0.276, Validation Accuracy:  0.351, Loss:  5.628
# Epoch   0 Batch   78/538 - Train Accuracy:  0.312, Validation Accuracy:  0.347, Loss:  5.609
# Epoch   0 Batch   79/538 - Train Accuracy:  0.343, Validation Accuracy:  0.385, Loss:  5.628
# Epoch   0 Batch   80/538 - Train Accuracy:  0.273, Validation Accuracy:  0.351, Loss:  5.639
# Epoch   0 Batch   81/538 - Train Accuracy:  0.273, Validation Accuracy:  0.351, Loss:  5.636
# Epoch   0 Batch   82/538 - Train Accuracy:  0.291, Validation Accuracy:  0.357, Loss:  5.630
# Epoch   0 Batch   83/538 - Train Accuracy:  0.314, Validation Accuracy:  0.385, Loss:  5.614
# Epoch   0 Batch   84/538 - Train Accuracy:  0.358, Validation Accuracy:  0.391, Loss:  5.625
# Epoch   0 Batch   85/538 - Train Accuracy:  0.317, Validation Accuracy:  0.317, Loss:  5.613
# Epoch   0 Batch   86/538 - Train Accuracy:  0.245, Validation Accuracy:  0.316, Loss:  5.630
# Epoch   0 Batch   87/538 - Train Accuracy:  0.294, Validation Accuracy:  0.354, Loss:  5.619
# Epoch   0 Batch   88/538 - Train Accuracy:  0.354, Validation Accuracy:  0.409, Loss:  5.639
# Epoch   0 Batch   89/538 - Train Accuracy:  0.351, Validation Accuracy:  0.410, Loss:  5.639
# Epoch   0 Batch   90/538 - Train Accuracy:  0.362, Validation Accuracy:  0.393, Loss:  5.622
# Epoch   0 Batch   91/538 - Train Accuracy:  0.307, Validation Accuracy:  0.382, Loss:  5.627
# Epoch   0 Batch   92/538 - Train Accuracy:  0.333, Validation Accuracy:  0.385, Loss:  5.628
# Epoch   0 Batch   93/538 - Train Accuracy:  0.336, Validation Accuracy:  0.409, Loss:  5.620
# Epoch   0 Batch   94/538 - Train Accuracy:  0.342, Validation Accuracy:  0.406, Loss:  5.668
# Epoch   0 Batch   95/538 - Train Accuracy:  0.410, Validation Accuracy:  0.408, Loss:  5.588
# Epoch   0 Batch   96/538 - Train Accuracy:  0.381, Validation Accuracy:  0.402, Loss:  5.591
# Epoch   0 Batch   97/538 - Train Accuracy:  0.314, Validation Accuracy:  0.386, Loss:  5.619
# Epoch   0 Batch   98/538 - Train Accuracy:  0.361, Validation Accuracy:  0.387, Loss:  5.598
# Epoch   0 Batch   99/538 - Train Accuracy:  0.319, Validation Accuracy:  0.381, Loss:  5.635
# Epoch   0 Batch  100/538 - Train Accuracy:  0.328, Validation Accuracy:  0.399, Loss:  5.620
# Epoch   0 Batch  101/538 - Train Accuracy:  0.341, Validation Accuracy:  0.405, Loss:  5.607
# Epoch   0 Batch  102/538 - Train Accuracy:  0.312, Validation Accuracy:  0.374, Loss:  5.611
# Epoch   0 Batch  103/538 - Train Accuracy:  0.361, Validation Accuracy:  0.398, Loss:  5.591
# Epoch   0 Batch  104/538 - Train Accuracy:  0.388, Validation Accuracy:  0.425, Loss:  5.601
# Epoch   0 Batch  105/538 - Train Accuracy:  0.369, Validation Accuracy:  0.404, Loss:  5.585
# Epoch   0 Batch  106/538 - Train Accuracy:  0.339, Validation Accuracy:  0.407, Loss:  5.582
# Epoch   0 Batch  107/538 - Train Accuracy:  0.339, Validation Accuracy:  0.408, Loss:  5.620
# Epoch   0 Batch  108/538 - Train Accuracy:  0.361, Validation Accuracy:  0.418, Loss:  5.581
# Epoch   0 Batch  109/538 - Train Accuracy:  0.326, Validation Accuracy:  0.391, Loss:  5.636
# Epoch   0 Batch  110/538 - Train Accuracy:  0.305, Validation Accuracy:  0.371, Loss:  5.612
# Epoch   0 Batch  111/538 - Train Accuracy:  0.377, Validation Accuracy:  0.410, Loss:  5.595
# Epoch   0 Batch  112/538 - Train Accuracy:  0.357, Validation Accuracy:  0.424, Loss:  5.621
# Epoch   0 Batch  113/538 - Train Accuracy:  0.361, Validation Accuracy:  0.425, Loss:  5.602
# Epoch   0 Batch  114/538 - Train Accuracy:  0.400, Validation Accuracy:  0.425, Loss:  5.596
# Epoch   0 Batch  115/538 - Train Accuracy:  0.360, Validation Accuracy:  0.421, Loss:  5.617
# Epoch   0 Batch  116/538 - Train Accuracy:  0.369, Validation Accuracy:  0.391, Loss:  5.578
# Epoch   0 Batch  117/538 - Train Accuracy:  0.351, Validation Accuracy:  0.384, Loss:  5.593
# Epoch   0 Batch  118/538 - Train Accuracy:  0.386, Validation Accuracy:  0.410, Loss:  5.603
# Epoch   0 Batch  119/538 - Train Accuracy:  0.404, Validation Accuracy:  0.431, Loss:  5.570
# Epoch   0 Batch  120/538 - Train Accuracy:  0.368, Validation Accuracy:  0.431, Loss:  5.593
# Epoch   0 Batch  121/538 - Train Accuracy:  0.412, Validation Accuracy:  0.440, Loss:  5.589
# Epoch   0 Batch  122/538 - Train Accuracy:  0.402, Validation Accuracy:  0.444, Loss:  5.573
# Epoch   0 Batch  123/538 - Train Accuracy:  0.387, Validation Accuracy:  0.421, Loss:  5.589
# Epoch   0 Batch  124/538 - Train Accuracy:  0.403, Validation Accuracy:  0.405, Loss:  5.611
# Epoch   0 Batch  125/538 - Train Accuracy:  0.374, Validation Accuracy:  0.401, Loss:  5.591
# Epoch   0 Batch  126/538 - Train Accuracy:  0.428, Validation Accuracy:  0.426, Loss:  5.592
# Epoch   0 Batch  127/538 - Train Accuracy:  0.376, Validation Accuracy:  0.443, Loss:  5.603
# Epoch   0 Batch  128/538 - Train Accuracy:  0.404, Validation Accuracy:  0.442, Loss:  5.605
# Epoch   0 Batch  129/538 - Train Accuracy:  0.411, Validation Accuracy:  0.447, Loss:  5.574
# Epoch   0 Batch  130/538 - Train Accuracy:  0.404, Validation Accuracy:  0.434, Loss:  5.596
# Epoch   0 Batch  131/538 - Train Accuracy:  0.357, Validation Accuracy:  0.413, Loss:  5.615
# Epoch   0 Batch  132/538 - Train Accuracy:  0.361, Validation Accuracy:  0.394, Loss:  5.584
# Epoch   0 Batch  133/538 - Train Accuracy:  0.393, Validation Accuracy:  0.402, Loss:  5.619
# Epoch   0 Batch  134/538 - Train Accuracy:  0.363, Validation Accuracy:  0.426, Loss:  5.634
# Epoch   0 Batch  135/538 - Train Accuracy:  0.399, Validation Accuracy:  0.431, Loss:  5.594
# Epoch   0 Batch  136/538 - Train Accuracy:  0.393, Validation Accuracy:  0.430, Loss:  5.583
# Epoch   0 Batch  137/538 - Train Accuracy:  0.386, Validation Accuracy:  0.427, Loss:  5.574
# Epoch   0 Batch  138/538 - Train Accuracy:  0.366, Validation Accuracy:  0.412, Loss:  5.590
# Epoch   0 Batch  139/538 - Train Accuracy:  0.352, Validation Accuracy:  0.423, Loss:  5.590
# Epoch   0 Batch  140/538 - Train Accuracy:  0.373, Validation Accuracy:  0.436, Loss:  5.588
# Epoch   0 Batch  141/538 - Train Accuracy:  0.399, Validation Accuracy:  0.452, Loss:  5.570
# Epoch   0 Batch  142/538 - Train Accuracy:  0.436, Validation Accuracy:  0.460, Loss:  5.566
# Epoch   0 Batch  143/538 - Train Accuracy:  0.384, Validation Accuracy:  0.458, Loss:  5.588
# Epoch   0 Batch  144/538 - Train Accuracy:  0.401, Validation Accuracy:  0.462, Loss:  5.573
# Epoch   0 Batch  145/538 - Train Accuracy:  0.420, Validation Accuracy:  0.461, Loss:  5.537
# Epoch   0 Batch  146/538 - Train Accuracy:  0.427, Validation Accuracy:  0.442, Loss:  5.590
# Epoch   0 Batch  147/538 - Train Accuracy:  0.414, Validation Accuracy:  0.435, Loss:  5.604
# Epoch   0 Batch  148/538 - Train Accuracy:  0.378, Validation Accuracy:  0.437, Loss:  5.622
# Epoch   0 Batch  149/538 - Train Accuracy:  0.398, Validation Accuracy:  0.454, Loss:  5.606
# Epoch   0 Batch  150/538 - Train Accuracy:  0.381, Validation Accuracy:  0.437, Loss:  5.593
# Epoch   0 Batch  151/538 - Train Accuracy:  0.407, Validation Accuracy:  0.436, Loss:  5.591
# Epoch   0 Batch  152/538 - Train Accuracy:  0.401, Validation Accuracy:  0.439, Loss:  5.565
# Epoch   0 Batch  153/538 - Train Accuracy:  0.378, Validation Accuracy:  0.423, Loss:  5.577
# Epoch   0 Batch  154/538 - Train Accuracy:  0.355, Validation Accuracy:  0.396, Loss:  5.590
# Epoch   0 Batch  155/538 - Train Accuracy:  0.356, Validation Accuracy:  0.393, Loss:  5.582
# Epoch   0 Batch  156/538 - Train Accuracy:  0.389, Validation Accuracy:  0.442, Loss:  5.599
# Epoch   0 Batch  157/538 - Train Accuracy:  0.410, Validation Accuracy:  0.442, Loss:  5.576
# Epoch   0 Batch  158/538 - Train Accuracy:  0.381, Validation Accuracy:  0.438, Loss:  5.567
# Epoch   0 Batch  159/538 - Train Accuracy:  0.382, Validation Accuracy:  0.444, Loss:  5.589
# Epoch   0 Batch  160/538 - Train Accuracy:  0.422, Validation Accuracy:  0.455, Loss:  5.565
# Epoch   0 Batch  161/538 - Train Accuracy:  0.413, Validation Accuracy:  0.454, Loss:  5.607
# Epoch   0 Batch  162/538 - Train Accuracy:  0.427, Validation Accuracy:  0.447, Loss:  5.582
# Epoch   0 Batch  163/538 - Train Accuracy:  0.382, Validation Accuracy:  0.409, Loss:  5.573
# Epoch   0 Batch  164/538 - Train Accuracy:  0.362, Validation Accuracy:  0.419, Loss:  5.591
# Epoch   0 Batch  165/538 - Train Accuracy:  0.411, Validation Accuracy:  0.427, Loss:  5.605
# Epoch   0 Batch  166/538 - Train Accuracy:  0.385, Validation Accuracy:  0.440, Loss:  5.580
# Epoch   0 Batch  167/538 - Train Accuracy:  0.428, Validation Accuracy:  0.448, Loss:  5.567
# Epoch   0 Batch  168/538 - Train Accuracy:  0.387, Validation Accuracy:  0.443, Loss:  5.580
# Epoch   0 Batch  169/538 - Train Accuracy:  0.387, Validation Accuracy:  0.442, Loss:  5.604
# Epoch   0 Batch  170/538 - Train Accuracy:  0.406, Validation Accuracy:  0.445, Loss:  5.607
# Epoch   0 Batch  171/538 - Train Accuracy:  0.387, Validation Accuracy:  0.456, Loss:  5.591
# Epoch   0 Batch  172/538 - Train Accuracy:  0.416, Validation Accuracy:  0.455, Loss:  5.574
# Epoch   0 Batch  173/538 - Train Accuracy:  0.417, Validation Accuracy:  0.448, Loss:  5.555
# Epoch   0 Batch  174/538 - Train Accuracy:  0.377, Validation Accuracy:  0.448, Loss:  5.598
# Epoch   0 Batch  175/538 - Train Accuracy:  0.376, Validation Accuracy:  0.441, Loss:  5.609
# Epoch   0 Batch  176/538 - Train Accuracy:  0.389, Validation Accuracy:  0.450, Loss:  5.580
# Epoch   0 Batch  177/538 - Train Accuracy:  0.416, Validation Accuracy:  0.448, Loss:  5.580
# Epoch   0 Batch  178/538 - Train Accuracy:  0.425, Validation Accuracy:  0.447, Loss:  5.538
# Epoch   0 Batch  179/538 - Train Accuracy:  0.397, Validation Accuracy:  0.450, Loss:  5.614
# Epoch   0 Batch  180/538 - Train Accuracy:  0.448, Validation Accuracy:  0.465, Loss:  5.564
# Epoch   0 Batch  181/538 - Train Accuracy:  0.386, Validation Accuracy:  0.458, Loss:  5.608
# Epoch   0 Batch  182/538 - Train Accuracy:  0.391, Validation Accuracy:  0.451, Loss:  5.554
# Epoch   0 Batch  183/538 - Train Accuracy:  0.428, Validation Accuracy:  0.460, Loss:  5.561
# Epoch   0 Batch  184/538 - Train Accuracy:  0.412, Validation Accuracy:  0.455, Loss:  5.592
# Epoch   0 Batch  185/538 - Train Accuracy:  0.391, Validation Accuracy:  0.446, Loss:  5.593
# Epoch   0 Batch  186/538 - Train Accuracy:  0.398, Validation Accuracy:  0.444, Loss:  5.584
# Epoch   0 Batch  187/538 - Train Accuracy:  0.429, Validation Accuracy:  0.441, Loss:  5.566
# Epoch   0 Batch  188/538 - Train Accuracy:  0.367, Validation Accuracy:  0.438, Loss:  5.570
# Epoch   0 Batch  189/538 - Train Accuracy:  0.384, Validation Accuracy:  0.440, Loss:  5.569
# Epoch   0 Batch  190/538 - Train Accuracy:  0.409, Validation Accuracy:  0.438, Loss:  5.543
# Epoch   0 Batch  191/538 - Train Accuracy:  0.410, Validation Accuracy:  0.444, Loss:  5.572
# Epoch   0 Batch  192/538 - Train Accuracy:  0.397, Validation Accuracy:  0.435, Loss:  5.577
# Epoch   0 Batch  193/538 - Train Accuracy:  0.419, Validation Accuracy:  0.438, Loss:  5.583
# Epoch   0 Batch  194/538 - Train Accuracy:  0.386, Validation Accuracy:  0.454, Loss:  5.585
# Epoch   0 Batch  195/538 - Train Accuracy:  0.420, Validation Accuracy:  0.448, Loss:  5.562
# Epoch   0 Batch  196/538 - Train Accuracy:  0.411, Validation Accuracy:  0.441, Loss:  5.577
# Epoch   0 Batch  197/538 - Train Accuracy:  0.441, Validation Accuracy:  0.453, Loss:  5.548
# Epoch   0 Batch  198/538 - Train Accuracy:  0.438, Validation Accuracy:  0.457, Loss:  5.578
# Epoch   0 Batch  199/538 - Train Accuracy:  0.394, Validation Accuracy:  0.457, Loss:  5.595
# Epoch   0 Batch  200/538 - Train Accuracy:  0.383, Validation Accuracy:  0.446, Loss:  5.575
# Epoch   0 Batch  201/538 - Train Accuracy:  0.426, Validation Accuracy:  0.444, Loss:  5.554
# Epoch   0 Batch  202/538 - Train Accuracy:  0.377, Validation Accuracy:  0.449, Loss:  5.589
# Epoch   0 Batch  203/538 - Train Accuracy:  0.403, Validation Accuracy:  0.454, Loss:  5.562
# Epoch   0 Batch  204/538 - Train Accuracy:  0.384, Validation Accuracy:  0.450, Loss:  5.572
# Epoch   0 Batch  205/538 - Train Accuracy:  0.413, Validation Accuracy:  0.443, Loss:  5.571
# Epoch   0 Batch  206/538 - Train Accuracy:  0.376, Validation Accuracy:  0.447, Loss:  5.592
# Epoch   0 Batch  207/538 - Train Accuracy:  0.422, Validation Accuracy:  0.453, Loss:  5.566
# Epoch   0 Batch  208/538 - Train Accuracy:  0.399, Validation Accuracy:  0.455, Loss:  5.576
# Epoch   0 Batch  209/538 - Train Accuracy:  0.385, Validation Accuracy:  0.453, Loss:  5.575
# Epoch   0 Batch  210/538 - Train Accuracy:  0.414, Validation Accuracy:  0.449, Loss:  5.574
# Epoch   0 Batch  211/538 - Train Accuracy:  0.397, Validation Accuracy:  0.457, Loss:  5.584
# Epoch   0 Batch  212/538 - Train Accuracy:  0.431, Validation Accuracy:  0.464, Loss:  5.561
# Epoch   0 Batch  213/538 - Train Accuracy:  0.399, Validation Accuracy:  0.451, Loss:  5.548
# Epoch   0 Batch  214/538 - Train Accuracy:  0.398, Validation Accuracy:  0.455, Loss:  5.596
# Epoch   0 Batch  215/538 - Train Accuracy:  0.390, Validation Accuracy:  0.450, Loss:  5.570
# Epoch   0 Batch  216/538 - Train Accuracy:  0.379, Validation Accuracy:  0.449, Loss:  5.589
# Epoch   0 Batch  217/538 - Train Accuracy:  0.406, Validation Accuracy:  0.443, Loss:  5.537
# Epoch   0 Batch  218/538 - Train Accuracy:  0.363, Validation Accuracy:  0.439, Loss:  5.593
# Epoch   0 Batch  219/538 - Train Accuracy:  0.385, Validation Accuracy:  0.450, Loss:  5.596
# Epoch   0 Batch  220/538 - Train Accuracy:  0.411, Validation Accuracy:  0.452, Loss:  5.577
# Epoch   0 Batch  221/538 - Train Accuracy:  0.421, Validation Accuracy:  0.463, Loss:  5.555
# Epoch   0 Batch  222/538 - Train Accuracy:  0.427, Validation Accuracy:  0.456, Loss:  5.561
# Epoch   0 Batch  223/538 - Train Accuracy:  0.382, Validation Accuracy:  0.450, Loss:  5.564
# Epoch   0 Batch  224/538 - Train Accuracy:  0.371, Validation Accuracy:  0.448, Loss:  5.586
# Epoch   0 Batch  225/538 - Train Accuracy:  0.416, Validation Accuracy:  0.449, Loss:  5.585
# Epoch   0 Batch  226/538 - Train Accuracy:  0.409, Validation Accuracy:  0.449, Loss:  5.547
# Epoch   0 Batch  227/538 - Train Accuracy:  0.444, Validation Accuracy:  0.447, Loss:  5.557
# Epoch   0 Batch  228/538 - Train Accuracy:  0.414, Validation Accuracy:  0.468, Loss:  5.552
# Epoch   0 Batch  229/538 - Train Accuracy:  0.409, Validation Accuracy:  0.448, Loss:  5.575
# Epoch   0 Batch  230/538 - Train Accuracy:  0.402, Validation Accuracy:  0.458, Loss:  5.580
# Epoch   0 Batch  231/538 - Train Accuracy:  0.415, Validation Accuracy:  0.461, Loss:  5.573
# Epoch   0 Batch  232/538 - Train Accuracy:  0.387, Validation Accuracy:  0.452, Loss:  5.564
# Epoch   0 Batch  233/538 - Train Accuracy:  0.436, Validation Accuracy:  0.461, Loss:  5.567
# Epoch   0 Batch  234/538 - Train Accuracy:  0.404, Validation Accuracy:  0.462, Loss:  5.579
# Epoch   0 Batch  235/538 - Train Accuracy:  0.430, Validation Accuracy:  0.461, Loss:  5.604
# Epoch   0 Batch  236/538 - Train Accuracy:  0.404, Validation Accuracy:  0.463, Loss:  5.541
# Epoch   0 Batch  237/538 - Train Accuracy:  0.418, Validation Accuracy:  0.466, Loss:  5.574
# Epoch   0 Batch  238/538 - Train Accuracy:  0.446, Validation Accuracy:  0.463, Loss:  5.559
# Epoch   0 Batch  239/538 - Train Accuracy:  0.406, Validation Accuracy:  0.464, Loss:  5.583
# Epoch   0 Batch  240/538 - Train Accuracy:  0.404, Validation Accuracy:  0.463, Loss:  5.560
# Epoch   0 Batch  241/538 - Train Accuracy:  0.399, Validation Accuracy:  0.458, Loss:  5.537
# Epoch   0 Batch  242/538 - Train Accuracy:  0.402, Validation Accuracy:  0.456, Loss:  5.584
# Epoch   0 Batch  243/538 - Train Accuracy:  0.369, Validation Accuracy:  0.456, Loss:  5.602
# Epoch   0 Batch  244/538 - Train Accuracy:  0.409, Validation Accuracy:  0.456, Loss:  5.581
# Epoch   0 Batch  245/538 - Train Accuracy:  0.385, Validation Accuracy:  0.444, Loss:  5.557
# Epoch   0 Batch  246/538 - Train Accuracy:  0.421, Validation Accuracy:  0.452, Loss:  5.563
# Epoch   0 Batch  247/538 - Train Accuracy:  0.369, Validation Accuracy:  0.449, Loss:  5.586
# Epoch   0 Batch  248/538 - Train Accuracy:  0.376, Validation Accuracy:  0.444, Loss:  5.571
# Epoch   0 Batch  249/538 - Train Accuracy:  0.411, Validation Accuracy:  0.450, Loss:  5.578
# Epoch   0 Batch  250/538 - Train Accuracy:  0.398, Validation Accuracy:  0.461, Loss:  5.559
# Epoch   0 Batch  251/538 - Train Accuracy:  0.391, Validation Accuracy:  0.466, Loss:  5.557
# Epoch   0 Batch  252/538 - Train Accuracy:  0.432, Validation Accuracy:  0.468, Loss:  5.562
# Epoch   0 Batch  253/538 - Train Accuracy:  0.436, Validation Accuracy:  0.466, Loss:  5.568
# Epoch   0 Batch  254/538 - Train Accuracy:  0.409, Validation Accuracy:  0.459, Loss:  5.550
# Epoch   0 Batch  255/538 - Train Accuracy:  0.390, Validation Accuracy:  0.450, Loss:  5.550
# Epoch   0 Batch  256/538 - Train Accuracy:  0.379, Validation Accuracy:  0.454, Loss:  5.580
# Epoch   0 Batch  257/538 - Train Accuracy:  0.424, Validation Accuracy:  0.464, Loss:  5.585
# Epoch   0 Batch  258/538 - Train Accuracy:  0.443, Validation Accuracy:  0.465, Loss:  5.583
# Epoch   0 Batch  259/538 - Train Accuracy:  0.415, Validation Accuracy:  0.454, Loss:  5.559
# Epoch   0 Batch  260/538 - Train Accuracy:  0.404, Validation Accuracy:  0.451, Loss:  5.569
# Epoch   0 Batch  261/538 - Train Accuracy:  0.389, Validation Accuracy:  0.457, Loss:  5.579
# Epoch   0 Batch  262/538 - Train Accuracy:  0.386, Validation Accuracy:  0.460, Loss:  5.562
# Epoch   0 Batch  263/538 - Train Accuracy:  0.418, Validation Accuracy:  0.465, Loss:  5.569
# Epoch   0 Batch  264/538 - Train Accuracy:  0.388, Validation Accuracy:  0.456, Loss:  5.566
# Epoch   0 Batch  265/538 - Train Accuracy:  0.376, Validation Accuracy:  0.449, Loss:  5.584
# Epoch   0 Batch  266/538 - Train Accuracy:  0.408, Validation Accuracy:  0.448, Loss:  5.548
# Epoch   0 Batch  267/538 - Train Accuracy:  0.390, Validation Accuracy:  0.456, Loss:  5.534
# Epoch   0 Batch  268/538 - Train Accuracy:  0.431, Validation Accuracy:  0.468, Loss:  5.562
# Epoch   0 Batch  269/538 - Train Accuracy:  0.405, Validation Accuracy:  0.466, Loss:  5.576
# Epoch   0 Batch  270/538 - Train Accuracy:  0.391, Validation Accuracy:  0.461, Loss:  5.562
# Epoch   0 Batch  271/538 - Train Accuracy:  0.395, Validation Accuracy:  0.458, Loss:  5.581
# Epoch   0 Batch  272/538 - Train Accuracy:  0.375, Validation Accuracy:  0.451, Loss:  5.571
# Epoch   0 Batch  273/538 - Train Accuracy:  0.408, Validation Accuracy:  0.464, Loss:  5.571
# Epoch   0 Batch  274/538 - Train Accuracy:  0.398, Validation Accuracy:  0.474, Loss:  5.552
# Epoch   0 Batch  275/538 - Train Accuracy:  0.400, Validation Accuracy:  0.454, Loss:  5.536
# Epoch   0 Batch  276/538 - Train Accuracy:  0.394, Validation Accuracy:  0.455, Loss:  5.557
# Epoch   0 Batch  277/538 - Train Accuracy:  0.408, Validation Accuracy:  0.458, Loss:  5.578
# Epoch   0 Batch  278/538 - Train Accuracy:  0.397, Validation Accuracy:  0.453, Loss:  5.555
# Epoch   0 Batch  279/538 - Train Accuracy:  0.391, Validation Accuracy:  0.445, Loss:  5.568
# Epoch   0 Batch  280/538 - Train Accuracy:  0.421, Validation Accuracy:  0.447, Loss:  5.568
# Epoch   0 Batch  281/538 - Train Accuracy:  0.400, Validation Accuracy:  0.456, Loss:  5.573
# Epoch   0 Batch  282/538 - Train Accuracy:  0.425, Validation Accuracy:  0.458, Loss:  5.554
# Epoch   0 Batch  283/538 - Train Accuracy:  0.395, Validation Accuracy:  0.448, Loss:  5.552
# Epoch   0 Batch  284/538 - Train Accuracy:  0.412, Validation Accuracy:  0.461, Loss:  5.562
# Epoch   0 Batch  285/538 - Train Accuracy:  0.441, Validation Accuracy:  0.474, Loss:  5.563
# Epoch   0 Batch  286/538 - Train Accuracy:  0.392, Validation Accuracy:  0.458, Loss:  5.538
# Epoch   0 Batch  287/538 - Train Accuracy:  0.422, Validation Accuracy:  0.456, Loss:  5.557
# Epoch   0 Batch  288/538 - Train Accuracy:  0.381, Validation Accuracy:  0.471, Loss:  5.547
# Epoch   0 Batch  289/538 - Train Accuracy:  0.434, Validation Accuracy:  0.469, Loss:  5.593
# Epoch   0 Batch  290/538 - Train Accuracy:  0.407, Validation Accuracy:  0.471, Loss:  5.551
# Epoch   0 Batch  291/538 - Train Accuracy:  0.421, Validation Accuracy:  0.465, Loss:  5.537
# Epoch   0 Batch  292/538 - Train Accuracy:  0.425, Validation Accuracy:  0.462, Loss:  5.525
# Epoch   0 Batch  293/538 - Train Accuracy:  0.420, Validation Accuracy:  0.461, Loss:  5.563
# Epoch   0 Batch  294/538 - Train Accuracy:  0.370, Validation Accuracy:  0.461, Loss:  5.564
# Epoch   0 Batch  295/538 - Train Accuracy:  0.455, Validation Accuracy:  0.462, Loss:  5.537
# Epoch   0 Batch  296/538 - Train Accuracy:  0.428, Validation Accuracy:  0.460, Loss:  5.527
# Epoch   0 Batch  297/538 - Train Accuracy:  0.389, Validation Accuracy:  0.467, Loss:  5.550
# Epoch   0 Batch  298/538 - Train Accuracy:  0.418, Validation Accuracy:  0.467, Loss:  5.571
# Epoch   0 Batch  299/538 - Train Accuracy:  0.433, Validation Accuracy:  0.472, Loss:  5.573
# Epoch   0 Batch  300/538 - Train Accuracy:  0.446, Validation Accuracy:  0.478, Loss:  5.558
# Epoch   0 Batch  301/538 - Train Accuracy:  0.436, Validation Accuracy:  0.479, Loss:  5.568
# Epoch   0 Batch  302/538 - Train Accuracy:  0.439, Validation Accuracy:  0.472, Loss:  5.557
# Epoch   0 Batch  303/538 - Train Accuracy:  0.451, Validation Accuracy:  0.452, Loss:  5.559
# Epoch   0 Batch  304/538 - Train Accuracy:  0.387, Validation Accuracy:  0.452, Loss:  5.590
# Epoch   0 Batch  305/538 - Train Accuracy:  0.388, Validation Accuracy:  0.444, Loss:  5.553
# Epoch   0 Batch  306/538 - Train Accuracy:  0.410, Validation Accuracy:  0.440, Loss:  5.560
# Epoch   0 Batch  307/538 - Train Accuracy:  0.384, Validation Accuracy:  0.441, Loss:  5.566
# Epoch   0 Batch  308/538 - Train Accuracy:  0.417, Validation Accuracy:  0.455, Loss:  5.571
# Epoch   0 Batch  309/538 - Train Accuracy:  0.403, Validation Accuracy:  0.472, Loss:  5.582
# Epoch   0 Batch  310/538 - Train Accuracy:  0.409, Validation Accuracy:  0.471, Loss:  5.525
# Epoch   0 Batch  311/538 - Train Accuracy:  0.441, Validation Accuracy:  0.464, Loss:  5.562
# Epoch   0 Batch  312/538 - Train Accuracy:  0.463, Validation Accuracy:  0.458, Loss:  5.561
# Epoch   0 Batch  313/538 - Train Accuracy:  0.396, Validation Accuracy:  0.456, Loss:  5.558
# Epoch   0 Batch  314/538 - Train Accuracy:  0.390, Validation Accuracy:  0.442, Loss:  5.555
# Epoch   0 Batch  315/538 - Train Accuracy:  0.411, Validation Accuracy:  0.450, Loss:  5.574
# Epoch   0 Batch  316/538 - Train Accuracy:  0.418, Validation Accuracy:  0.456, Loss:  5.568
# Epoch   0 Batch  317/538 - Train Accuracy:  0.416, Validation Accuracy:  0.470, Loss:  5.576
# Epoch   0 Batch  318/538 - Train Accuracy:  0.439, Validation Accuracy:  0.474, Loss:  5.546
# Epoch   0 Batch  319/538 - Train Accuracy:  0.433, Validation Accuracy:  0.470, Loss:  5.534
# Epoch   0 Batch  320/538 - Train Accuracy:  0.443, Validation Accuracy:  0.477, Loss:  5.568
# Epoch   0 Batch  321/538 - Train Accuracy:  0.432, Validation Accuracy:  0.463, Loss:  5.548
# Epoch   0 Batch  322/538 - Train Accuracy:  0.421, Validation Accuracy:  0.455, Loss:  5.525
# Epoch   0 Batch  323/538 - Train Accuracy:  0.419, Validation Accuracy:  0.456, Loss:  5.543
# Epoch   0 Batch  324/538 - Train Accuracy:  0.394, Validation Accuracy:  0.464, Loss:  5.566
# Epoch   0 Batch  325/538 - Train Accuracy:  0.439, Validation Accuracy:  0.475, Loss:  5.525
# Epoch   0 Batch  326/538 - Train Accuracy:  0.411, Validation Accuracy:  0.471, Loss:  5.576
# Epoch   0 Batch  327/538 - Train Accuracy:  0.433, Validation Accuracy:  0.478, Loss:  5.556
# Epoch   0 Batch  328/538 - Train Accuracy:  0.426, Validation Accuracy:  0.468, Loss:  5.551
# Epoch   0 Batch  329/538 - Train Accuracy:  0.413, Validation Accuracy:  0.451, Loss:  5.553
# Epoch   0 Batch  330/538 - Train Accuracy:  0.421, Validation Accuracy:  0.454, Loss:  5.527
# Epoch   0 Batch  331/538 - Train Accuracy:  0.381, Validation Accuracy:  0.453, Loss:  5.564
# Epoch   0 Batch  332/538 - Train Accuracy:  0.407, Validation Accuracy:  0.459, Loss:  5.552
# Epoch   0 Batch  333/538 - Train Accuracy:  0.433, Validation Accuracy:  0.462, Loss:  5.544
# Epoch   0 Batch  334/538 - Train Accuracy:  0.464, Validation Accuracy:  0.460, Loss:  5.523
# Epoch   0 Batch  335/538 - Train Accuracy:  0.437, Validation Accuracy:  0.469, Loss:  5.576
# Epoch   0 Batch  336/538 - Train Accuracy:  0.446, Validation Accuracy:  0.473, Loss:  5.542
# Epoch   0 Batch  337/538 - Train Accuracy:  0.442, Validation Accuracy:  0.474, Loss:  5.549
# Epoch   0 Batch  338/538 - Train Accuracy:  0.437, Validation Accuracy:  0.481, Loss:  5.554
# Epoch   0 Batch  339/538 - Train Accuracy:  0.448, Validation Accuracy:  0.481, Loss:  5.545
# Epoch   0 Batch  340/538 - Train Accuracy:  0.393, Validation Accuracy:  0.472, Loss:  5.528
# Epoch   0 Batch  341/538 - Train Accuracy:  0.411, Validation Accuracy:  0.478, Loss:  5.553
# Epoch   0 Batch  342/538 - Train Accuracy:  0.445, Validation Accuracy:  0.465, Loss:  5.527
# Epoch   0 Batch  343/538 - Train Accuracy:  0.426, Validation Accuracy:  0.470, Loss:  5.545
# Epoch   0 Batch  344/538 - Train Accuracy:  0.389, Validation Accuracy:  0.451, Loss:  5.556
# Epoch   0 Batch  345/538 - Train Accuracy:  0.431, Validation Accuracy:  0.454, Loss:  5.567
# Epoch   0 Batch  346/538 - Train Accuracy:  0.431, Validation Accuracy:  0.455, Loss:  5.555
# Epoch   0 Batch  347/538 - Train Accuracy:  0.406, Validation Accuracy:  0.456, Loss:  5.546
# Epoch   0 Batch  348/538 - Train Accuracy:  0.423, Validation Accuracy:  0.456, Loss:  5.544
# Epoch   0 Batch  349/538 - Train Accuracy:  0.400, Validation Accuracy:  0.461, Loss:  5.589
# Epoch   0 Batch  350/538 - Train Accuracy:  0.418, Validation Accuracy:  0.457, Loss:  5.558
# Epoch   0 Batch  351/538 - Train Accuracy:  0.362, Validation Accuracy:  0.436, Loss:  5.561
# Epoch   0 Batch  352/538 - Train Accuracy:  0.399, Validation Accuracy:  0.439, Loss:  5.553
# Epoch   0 Batch  353/538 - Train Accuracy:  0.402, Validation Accuracy:  0.453, Loss:  5.550
# Epoch   0 Batch  354/538 - Train Accuracy:  0.394, Validation Accuracy:  0.459, Loss:  5.575
# Epoch   0 Batch  355/538 - Train Accuracy:  0.387, Validation Accuracy:  0.462, Loss:  5.556
# Epoch   0 Batch  356/538 - Train Accuracy:  0.443, Validation Accuracy:  0.456, Loss:  5.550
# Epoch   0 Batch  357/538 - Train Accuracy:  0.401, Validation Accuracy:  0.456, Loss:  5.557
# Epoch   0 Batch  358/538 - Train Accuracy:  0.398, Validation Accuracy:  0.460, Loss:  5.586
# Epoch   0 Batch  359/538 - Train Accuracy:  0.437, Validation Accuracy:  0.472, Loss:  5.564
# Epoch   0 Batch  360/538 - Train Accuracy:  0.403, Validation Accuracy:  0.461, Loss:  5.555
# Epoch   0 Batch  361/538 - Train Accuracy:  0.415, Validation Accuracy:  0.444, Loss:  5.544
# Epoch   0 Batch  362/538 - Train Accuracy:  0.408, Validation Accuracy:  0.448, Loss:  5.548
# Epoch   0 Batch  363/538 - Train Accuracy:  0.418, Validation Accuracy:  0.442, Loss:  5.519
# Epoch   0 Batch  364/538 - Train Accuracy:  0.384, Validation Accuracy:  0.452, Loss:  5.529
# Epoch   0 Batch  365/538 - Train Accuracy:  0.406, Validation Accuracy:  0.461, Loss:  5.534
# Epoch   0 Batch  366/538 - Train Accuracy:  0.415, Validation Accuracy:  0.465, Loss:  5.534
# Epoch   0 Batch  367/538 - Train Accuracy:  0.397, Validation Accuracy:  0.466, Loss:  5.521
# Epoch   0 Batch  368/538 - Train Accuracy:  0.506, Validation Accuracy:  0.472, Loss:  5.535
# Epoch   0 Batch  369/538 - Train Accuracy:  0.418, Validation Accuracy:  0.481, Loss:  5.534
# Epoch   0 Batch  370/538 - Train Accuracy:  0.388, Validation Accuracy:  0.454, Loss:  5.537
# Epoch   0 Batch  371/538 - Train Accuracy:  0.416, Validation Accuracy:  0.442, Loss:  5.524
# Epoch   0 Batch  372/538 - Train Accuracy:  0.409, Validation Accuracy:  0.453, Loss:  5.557
# Epoch   0 Batch  373/538 - Train Accuracy:  0.399, Validation Accuracy:  0.464, Loss:  5.588
# Epoch   0 Batch  374/538 - Train Accuracy:  0.400, Validation Accuracy:  0.470, Loss:  5.549
# Epoch   0 Batch  375/538 - Train Accuracy:  0.440, Validation Accuracy:  0.469, Loss:  5.544
# Epoch   0 Batch  376/538 - Train Accuracy:  0.398, Validation Accuracy:  0.468, Loss:  5.546
# Epoch   0 Batch  377/538 - Train Accuracy:  0.414, Validation Accuracy:  0.462, Loss:  5.547
# Epoch   0 Batch  378/538 - Train Accuracy:  0.445, Validation Accuracy:  0.482, Loss:  5.551
# Epoch   0 Batch  379/538 - Train Accuracy:  0.438, Validation Accuracy:  0.472, Loss:  5.561
# Epoch   0 Batch  380/538 - Train Accuracy:  0.419, Validation Accuracy:  0.467, Loss:  5.552
# Epoch   0 Batch  381/538 - Train Accuracy:  0.426, Validation Accuracy:  0.476, Loss:  5.554
# Epoch   0 Batch  382/538 - Train Accuracy:  0.396, Validation Accuracy:  0.461, Loss:  5.548
# Epoch   0 Batch  383/538 - Train Accuracy:  0.396, Validation Accuracy:  0.455, Loss:  5.574
# Epoch   0 Batch  384/538 - Train Accuracy:  0.417, Validation Accuracy:  0.462, Loss:  5.551
# Epoch   0 Batch  385/538 - Train Accuracy:  0.412, Validation Accuracy:  0.463, Loss:  5.541
# Epoch   0 Batch  386/538 - Train Accuracy:  0.396, Validation Accuracy:  0.463, Loss:  5.563
# Epoch   0 Batch  387/538 - Train Accuracy:  0.393, Validation Accuracy:  0.459, Loss:  5.526
# Epoch   0 Batch  388/538 - Train Accuracy:  0.418, Validation Accuracy:  0.459, Loss:  5.569
# Epoch   0 Batch  389/538 - Train Accuracy:  0.426, Validation Accuracy:  0.472, Loss:  5.548
# Epoch   0 Batch  390/538 - Train Accuracy:  0.422, Validation Accuracy:  0.459, Loss:  5.549
# Epoch   0 Batch  391/538 - Train Accuracy:  0.424, Validation Accuracy:  0.451, Loss:  5.521
# Epoch   0 Batch  392/538 - Train Accuracy:  0.423, Validation Accuracy:  0.459, Loss:  5.543
# Epoch   0 Batch  393/538 - Train Accuracy:  0.438, Validation Accuracy:  0.465, Loss:  5.521
# Epoch   0 Batch  394/538 - Train Accuracy:  0.386, Validation Accuracy:  0.475, Loss:  5.523
# Epoch   0 Batch  395/538 - Train Accuracy:  0.389, Validation Accuracy:  0.460, Loss:  5.553
# Epoch   0 Batch  396/538 - Train Accuracy:  0.380, Validation Accuracy:  0.450, Loss:  5.533
# Epoch   0 Batch  397/538 - Train Accuracy:  0.393, Validation Accuracy:  0.451, Loss:  5.531
# Epoch   0 Batch  398/538 - Train Accuracy:  0.399, Validation Accuracy:  0.460, Loss:  5.558
# Epoch   0 Batch  399/538 - Train Accuracy:  0.403, Validation Accuracy:  0.466, Loss:  5.550
# Epoch   0 Batch  400/538 - Train Accuracy:  0.426, Validation Accuracy:  0.467, Loss:  5.558
# Epoch   0 Batch  401/538 - Train Accuracy:  0.397, Validation Accuracy:  0.455, Loss:  5.535
# Epoch   0 Batch  402/538 - Train Accuracy:  0.398, Validation Accuracy:  0.455, Loss:  5.535
# Epoch   0 Batch  403/538 - Train Accuracy:  0.387, Validation Accuracy:  0.454, Loss:  5.565
# Epoch   0 Batch  404/538 - Train Accuracy:  0.423, Validation Accuracy:  0.458, Loss:  5.535
# Epoch   0 Batch  405/538 - Train Accuracy:  0.406, Validation Accuracy:  0.457, Loss:  5.576
# Epoch   0 Batch  406/538 - Train Accuracy:  0.424, Validation Accuracy:  0.461, Loss:  5.526
# Epoch   0 Batch  407/538 - Train Accuracy:  0.425, Validation Accuracy:  0.464, Loss:  5.532
# Epoch   0 Batch  408/538 - Train Accuracy:  0.397, Validation Accuracy:  0.461, Loss:  5.554
# Epoch   0 Batch  409/538 - Train Accuracy:  0.396, Validation Accuracy:  0.464, Loss:  5.550
# Epoch   0 Batch  410/538 - Train Accuracy:  0.414, Validation Accuracy:  0.463, Loss:  5.548
# Epoch   0 Batch  411/538 - Train Accuracy:  0.417, Validation Accuracy:  0.471, Loss:  5.520
# Epoch   0 Batch  412/538 - Train Accuracy:  0.421, Validation Accuracy:  0.462, Loss:  5.531
# Epoch   0 Batch  413/538 - Train Accuracy:  0.384, Validation Accuracy:  0.447, Loss:  5.526
# Epoch   0 Batch  414/538 - Train Accuracy:  0.395, Validation Accuracy:  0.448, Loss:  5.534
# Epoch   0 Batch  415/538 - Train Accuracy:  0.387, Validation Accuracy:  0.455, Loss:  5.538
# Epoch   0 Batch  416/538 - Train Accuracy:  0.452, Validation Accuracy:  0.450, Loss:  5.515
# Epoch   0 Batch  417/538 - Train Accuracy:  0.418, Validation Accuracy:  0.481, Loss:  5.509
# Epoch   0 Batch  418/538 - Train Accuracy:  0.421, Validation Accuracy:  0.485, Loss:  5.516
# Epoch   0 Batch  419/538 - Train Accuracy:  0.417, Validation Accuracy:  0.476, Loss:  5.526
# Epoch   0 Batch  420/538 - Train Accuracy:  0.418, Validation Accuracy:  0.478, Loss:  5.546
# Epoch   0 Batch  421/538 - Train Accuracy:  0.449, Validation Accuracy:  0.490, Loss:  5.522
# Epoch   0 Batch  422/538 - Train Accuracy:  0.440, Validation Accuracy:  0.485, Loss:  5.503
# Epoch   0 Batch  423/538 - Train Accuracy:  0.424, Validation Accuracy:  0.464, Loss:  5.555
# Epoch   0 Batch  424/538 - Train Accuracy:  0.432, Validation Accuracy:  0.461, Loss:  5.522
# Epoch   0 Batch  425/538 - Train Accuracy:  0.434, Validation Accuracy:  0.468, Loss:  5.522
# Epoch   0 Batch  426/538 - Train Accuracy:  0.439, Validation Accuracy:  0.470, Loss:  5.535
# Epoch   0 Batch  427/538 - Train Accuracy:  0.410, Validation Accuracy:  0.469, Loss:  5.550
# Epoch   0 Batch  428/538 - Train Accuracy:  0.449, Validation Accuracy:  0.470, Loss:  5.510
# Epoch   0 Batch  429/538 - Train Accuracy:  0.437, Validation Accuracy:  0.455, Loss:  5.503
# Epoch   0 Batch  430/538 - Train Accuracy:  0.415, Validation Accuracy:  0.459, Loss:  5.540
# Epoch   0 Batch  431/538 - Train Accuracy:  0.408, Validation Accuracy:  0.455, Loss:  5.530
# Epoch   0 Batch  432/538 - Train Accuracy:  0.466, Validation Accuracy:  0.467, Loss:  5.534
# Epoch   0 Batch  433/538 - Train Accuracy:  0.406, Validation Accuracy:  0.477, Loss:  5.507
# Epoch   0 Batch  434/538 - Train Accuracy:  0.415, Validation Accuracy:  0.479, Loss:  5.560
# Epoch   0 Batch  435/538 - Train Accuracy:  0.410, Validation Accuracy:  0.466, Loss:  5.543
# Epoch   0 Batch  436/538 - Train Accuracy:  0.395, Validation Accuracy:  0.467, Loss:  5.542
# Epoch   0 Batch  437/538 - Train Accuracy:  0.404, Validation Accuracy:  0.467, Loss:  5.551
# Epoch   0 Batch  438/538 - Train Accuracy:  0.416, Validation Accuracy:  0.461, Loss:  5.545
# Epoch   0 Batch  439/538 - Train Accuracy:  0.431, Validation Accuracy:  0.462, Loss:  5.552
# Epoch   0 Batch  440/538 - Train Accuracy:  0.394, Validation Accuracy:  0.465, Loss:  5.550
# Epoch   0 Batch  441/538 - Train Accuracy:  0.393, Validation Accuracy:  0.476, Loss:  5.532
# Epoch   0 Batch  442/538 - Train Accuracy:  0.440, Validation Accuracy:  0.465, Loss:  5.517
# Epoch   0 Batch  443/538 - Train Accuracy:  0.419, Validation Accuracy:  0.462, Loss:  5.536
# Epoch   0 Batch  444/538 - Train Accuracy:  0.443, Validation Accuracy:  0.460, Loss:  5.529
# Epoch   0 Batch  445/538 - Train Accuracy:  0.407, Validation Accuracy:  0.470, Loss:  5.528
# Epoch   0 Batch  446/538 - Train Accuracy:  0.436, Validation Accuracy:  0.469, Loss:  5.515
# Epoch   0 Batch  447/538 - Train Accuracy:  0.397, Validation Accuracy:  0.469, Loss:  5.523
# Epoch   0 Batch  448/538 - Train Accuracy:  0.448, Validation Accuracy:  0.475, Loss:  5.529
# Epoch   0 Batch  449/538 - Train Accuracy:  0.401, Validation Accuracy:  0.466, Loss:  5.571
# Epoch   0 Batch  450/538 - Train Accuracy:  0.424, Validation Accuracy:  0.463, Loss:  5.541
# Epoch   0 Batch  451/538 - Train Accuracy:  0.414, Validation Accuracy:  0.471, Loss:  5.543
# Epoch   0 Batch  452/538 - Train Accuracy:  0.426, Validation Accuracy:  0.470, Loss:  5.526
# Epoch   0 Batch  453/538 - Train Accuracy:  0.417, Validation Accuracy:  0.470, Loss:  5.532
# Epoch   0 Batch  454/538 - Train Accuracy:  0.443, Validation Accuracy:  0.469, Loss:  5.534
# Epoch   0 Batch  455/538 - Train Accuracy:  0.463, Validation Accuracy:  0.466, Loss:  5.534
# Epoch   0 Batch  456/538 - Train Accuracy:  0.515, Validation Accuracy:  0.474, Loss:  5.531
# Epoch   0 Batch  457/538 - Train Accuracy:  0.412, Validation Accuracy:  0.468, Loss:  5.564
# Epoch   0 Batch  458/538 - Train Accuracy:  0.446, Validation Accuracy:  0.488, Loss:  5.546
# Epoch   0 Batch  459/538 - Train Accuracy:  0.434, Validation Accuracy:  0.483, Loss:  5.527
# Epoch   0 Batch  460/538 - Train Accuracy:  0.433, Validation Accuracy:  0.479, Loss:  5.510
# Epoch   0 Batch  461/538 - Train Accuracy:  0.381, Validation Accuracy:  0.469, Loss:  5.533
# Epoch   0 Batch  462/538 - Train Accuracy:  0.411, Validation Accuracy:  0.464, Loss:  5.514
# Epoch   0 Batch  463/538 - Train Accuracy:  0.395, Validation Accuracy:  0.465, Loss:  5.523
# Epoch   0 Batch  464/538 - Train Accuracy:  0.397, Validation Accuracy:  0.467, Loss:  5.513
# Epoch   0 Batch  465/538 - Train Accuracy:  0.386, Validation Accuracy:  0.461, Loss:  5.506
# Epoch   0 Batch  466/538 - Train Accuracy:  0.367, Validation Accuracy:  0.471, Loss:  5.552
# Epoch   0 Batch  467/538 - Train Accuracy:  0.419, Validation Accuracy:  0.473, Loss:  5.525
# Epoch   0 Batch  468/538 - Train Accuracy:  0.431, Validation Accuracy:  0.466, Loss:  5.517
# Epoch   0 Batch  469/538 - Train Accuracy:  0.427, Validation Accuracy:  0.478, Loss:  5.573
# Epoch   0 Batch  470/538 - Train Accuracy:  0.448, Validation Accuracy:  0.479, Loss:  5.514
# Epoch   0 Batch  471/538 - Train Accuracy:  0.453, Validation Accuracy:  0.477, Loss:  5.576
# Epoch   0 Batch  472/538 - Train Accuracy:  0.420, Validation Accuracy:  0.467, Loss:  5.542
# Epoch   0 Batch  473/538 - Train Accuracy:  0.415, Validation Accuracy:  0.470, Loss:  5.513
# Epoch   0 Batch  474/538 - Train Accuracy:  0.448, Validation Accuracy:  0.479, Loss:  5.506
# Epoch   0 Batch  475/538 - Train Accuracy:  0.461, Validation Accuracy:  0.481, Loss:  5.529
# Epoch   0 Batch  476/538 - Train Accuracy:  0.391, Validation Accuracy:  0.469, Loss:  5.517
# Epoch   0 Batch  477/538 - Train Accuracy:  0.402, Validation Accuracy:  0.472, Loss:  5.519
# Epoch   0 Batch  478/538 - Train Accuracy:  0.419, Validation Accuracy:  0.463, Loss:  5.515
# Epoch   0 Batch  479/538 - Train Accuracy:  0.423, Validation Accuracy:  0.462, Loss:  5.492
# Epoch   0 Batch  480/538 - Train Accuracy:  0.429, Validation Accuracy:  0.471, Loss:  5.511
# Epoch   0 Batch  481/538 - Train Accuracy:  0.429, Validation Accuracy:  0.450, Loss:  5.551
# Epoch   0 Batch  482/538 - Train Accuracy:  0.475, Validation Accuracy:  0.449, Loss:  5.514
# Epoch   0 Batch  483/538 - Train Accuracy:  0.412, Validation Accuracy:  0.452, Loss:  5.515
# Epoch   0 Batch  484/538 - Train Accuracy:  0.441, Validation Accuracy:  0.455, Loss:  5.509
# Epoch   0 Batch  485/538 - Train Accuracy:  0.426, Validation Accuracy:  0.449, Loss:  5.500
# Epoch   0 Batch  486/538 - Train Accuracy:  0.420, Validation Accuracy:  0.449, Loss:  5.526
# Epoch   0 Batch  487/538 - Train Accuracy:  0.436, Validation Accuracy:  0.463, Loss:  5.516
# Epoch   0 Batch  488/538 - Train Accuracy:  0.438, Validation Accuracy:  0.468, Loss:  5.508
# Epoch   0 Batch  489/538 - Train Accuracy:  0.401, Validation Accuracy:  0.471, Loss:  5.537
# Epoch   0 Batch  490/538 - Train Accuracy:  0.420, Validation Accuracy:  0.453, Loss:  5.528
# Epoch   0 Batch  491/538 - Train Accuracy:  0.399, Validation Accuracy:  0.470, Loss:  5.540
# Epoch   0 Batch  492/538 - Train Accuracy:  0.415, Validation Accuracy:  0.465, Loss:  5.532
# Epoch   0 Batch  493/538 - Train Accuracy:  0.422, Validation Accuracy:  0.453, Loss:  5.524
# Epoch   0 Batch  494/538 - Train Accuracy:  0.399, Validation Accuracy:  0.448, Loss:  5.515
# Epoch   0 Batch  495/538 - Train Accuracy:  0.407, Validation Accuracy:  0.452, Loss:  5.529
# Epoch   0 Batch  496/538 - Train Accuracy:  0.422, Validation Accuracy:  0.466, Loss:  5.539
# Epoch   0 Batch  497/538 - Train Accuracy:  0.424, Validation Accuracy:  0.450, Loss:  5.547
# Epoch   0 Batch  498/538 - Train Accuracy:  0.382, Validation Accuracy:  0.449, Loss:  5.497
# Epoch   0 Batch  499/538 - Train Accuracy:  0.419, Validation Accuracy:  0.434, Loss:  5.530
# Epoch   0 Batch  500/538 - Train Accuracy:  0.447, Validation Accuracy:  0.454, Loss:  5.509
# Epoch   0 Batch  501/538 - Train Accuracy:  0.422, Validation Accuracy:  0.441, Loss:  5.542
# Epoch   0 Batch  502/538 - Train Accuracy:  0.402, Validation Accuracy:  0.467, Loss:  5.529
# Epoch   0 Batch  503/538 - Train Accuracy:  0.455, Validation Accuracy:  0.477, Loss:  5.522
# Epoch   0 Batch  504/538 - Train Accuracy:  0.422, Validation Accuracy:  0.481, Loss:  5.538
# Epoch   0 Batch  505/538 - Train Accuracy:  0.428, Validation Accuracy:  0.479, Loss:  5.517
# Epoch   0 Batch  506/538 - Train Accuracy:  0.420, Validation Accuracy:  0.477, Loss:  5.532
# Epoch   0 Batch  507/538 - Train Accuracy:  0.433, Validation Accuracy:  0.490, Loss:  5.509
# Epoch   0 Batch  508/538 - Train Accuracy:  0.454, Validation Accuracy:  0.485, Loss:  5.502
# Epoch   0 Batch  509/538 - Train Accuracy:  0.389, Validation Accuracy:  0.464, Loss:  5.536
# Epoch   0 Batch  510/538 - Train Accuracy:  0.427, Validation Accuracy:  0.464, Loss:  5.513
# Epoch   0 Batch  511/538 - Train Accuracy:  0.488, Validation Accuracy:  0.487, Loss:  5.541
# Epoch   0 Batch  512/538 - Train Accuracy:  0.466, Validation Accuracy:  0.482, Loss:  5.502
# Epoch   0 Batch  513/538 - Train Accuracy:  0.440, Validation Accuracy:  0.473, Loss:  5.511
# Epoch   0 Batch  514/538 - Train Accuracy:  0.407, Validation Accuracy:  0.461, Loss:  5.523
# Epoch   0 Batch  515/538 - Train Accuracy:  0.428, Validation Accuracy:  0.458, Loss:  5.542
# ...
# Epoch   9 Batch  375/538 - Train Accuracy:  0.364, Validation Accuracy:  0.400, Loss:  5.507
# Epoch   9 Batch  376/538 - Train Accuracy:  0.341, Validation Accuracy:  0.401, Loss:  5.489
# Epoch   9 Batch  377/538 - Train Accuracy:  0.348, Validation Accuracy:  0.402, Loss:  5.469
# Epoch   9 Batch  378/538 - Train Accuracy:  0.391, Validation Accuracy:  0.403, Loss:  5.470
# Epoch   9 Batch  379/538 - Train Accuracy:  0.389, Validation Accuracy:  0.403, Loss:  5.479
# Epoch   9 Batch  380/538 - Train Accuracy:  0.362, Validation Accuracy:  0.404, Loss:  5.452
# Epoch   9 Batch  381/538 - Train Accuracy:  0.361, Validation Accuracy:  0.403, Loss:  5.465
# Epoch   9 Batch  382/538 - Train Accuracy:  0.326, Validation Accuracy:  0.401, Loss:  5.506
# Epoch   9 Batch  383/538 - Train Accuracy:  0.335, Validation Accuracy:  0.400, Loss:  5.460
# Epoch   9 Batch  384/538 - Train Accuracy:  0.367, Validation Accuracy:  0.401, Loss:  5.466
# Epoch   9 Batch  385/538 - Train Accuracy:  0.366, Validation Accuracy:  0.404, Loss:  5.464
# Epoch   9 Batch  386/538 - Train Accuracy:  0.346, Validation Accuracy:  0.404, Loss:  5.468
# Epoch   9 Batch  387/538 - Train Accuracy:  0.330, Validation Accuracy:  0.402, Loss:  5.429
# Epoch   9 Batch  388/538 - Train Accuracy:  0.365, Validation Accuracy:  0.401, Loss:  5.476
# Epoch   9 Batch  389/538 - Train Accuracy:  0.330, Validation Accuracy:  0.399, Loss:  5.479
# Epoch   9 Batch  390/538 - Train Accuracy:  0.344, Validation Accuracy:  0.397, Loss:  5.463
# Epoch   9 Batch  391/538 - Train Accuracy:  0.362, Validation Accuracy:  0.401, Loss:  5.433
# Epoch   9 Batch  392/538 - Train Accuracy:  0.340, Validation Accuracy:  0.408, Loss:  5.428
# Epoch   9 Batch  393/538 - Train Accuracy:  0.373, Validation Accuracy:  0.404, Loss:  5.468
# Epoch   9 Batch  394/538 - Train Accuracy:  0.306, Validation Accuracy:  0.396, Loss:  5.482
# Epoch   9 Batch  395/538 - Train Accuracy:  0.337, Validation Accuracy:  0.388, Loss:  5.464
# Epoch   9 Batch  396/538 - Train Accuracy:  0.311, Validation Accuracy:  0.386, Loss:  5.445
# Epoch   9 Batch  397/538 - Train Accuracy:  0.330, Validation Accuracy:  0.388, Loss:  5.472
# Epoch   9 Batch  398/538 - Train Accuracy:  0.333, Validation Accuracy:  0.393, Loss:  5.499
# Epoch   9 Batch  399/538 - Train Accuracy:  0.336, Validation Accuracy:  0.399, Loss:  5.462
# Epoch   9 Batch  400/538 - Train Accuracy:  0.350, Validation Accuracy:  0.398, Loss:  5.474
# Epoch   9 Batch  401/538 - Train Accuracy:  0.320, Validation Accuracy:  0.397, Loss:  5.503
# Epoch   9 Batch  402/538 - Train Accuracy:  0.346, Validation Accuracy:  0.393, Loss:  5.475
# Epoch   9 Batch  403/538 - Train Accuracy:  0.320, Validation Accuracy:  0.391, Loss:  5.485
# Epoch   9 Batch  404/538 - Train Accuracy:  0.360, Validation Accuracy:  0.390, Loss:  5.511
# Epoch   9 Batch  405/538 - Train Accuracy:  0.337, Validation Accuracy:  0.390, Loss:  5.483
# Epoch   9 Batch  406/538 - Train Accuracy:  0.341, Validation Accuracy:  0.391, Loss:  5.478
# Epoch   9 Batch  407/538 - Train Accuracy:  0.332, Validation Accuracy:  0.390, Loss:  5.468
# Epoch   9 Batch  408/538 - Train Accuracy:  0.325, Validation Accuracy:  0.394, Loss:  5.445
# Epoch   9 Batch  409/538 - Train Accuracy:  0.295, Validation Accuracy:  0.395, Loss:  5.452
# Epoch   9 Batch  410/538 - Train Accuracy:  0.329, Validation Accuracy:  0.395, Loss:  5.475
# Epoch   9 Batch  411/538 - Train Accuracy:  0.360, Validation Accuracy:  0.397, Loss:  5.508
# Epoch   9 Batch  412/538 - Train Accuracy:  0.366, Validation Accuracy:  0.397, Loss:  5.438
# Epoch   9 Batch  413/538 - Train Accuracy:  0.311, Validation Accuracy:  0.395, Loss:  5.446
# Epoch   9 Batch  414/538 - Train Accuracy:  0.308, Validation Accuracy:  0.392, Loss:  5.464
# Epoch   9 Batch  415/538 - Train Accuracy:  0.304, Validation Accuracy:  0.387, Loss:  5.479
# Epoch   9 Batch  416/538 - Train Accuracy:  0.368, Validation Accuracy:  0.387, Loss:  5.483
# Epoch   9 Batch  417/538 - Train Accuracy:  0.338, Validation Accuracy:  0.387, Loss:  5.497
# Epoch   9 Batch  418/538 - Train Accuracy:  0.322, Validation Accuracy:  0.381, Loss:  5.485
# Epoch   9 Batch  419/538 - Train Accuracy:  0.317, Validation Accuracy:  0.379, Loss:  5.463
# Epoch   9 Batch  420/538 - Train Accuracy:  0.316, Validation Accuracy:  0.384, Loss:  5.492
# Epoch   9 Batch  421/538 - Train Accuracy:  0.356, Validation Accuracy:  0.386, Loss:  5.463
# Epoch   9 Batch  422/538 - Train Accuracy:  0.332, Validation Accuracy:  0.388, Loss:  5.471
# Epoch   9 Batch  423/538 - Train Accuracy:  0.329, Validation Accuracy:  0.395, Loss:  5.473
# Epoch   9 Batch  424/538 - Train Accuracy:  0.344, Validation Accuracy:  0.400, Loss:  5.454
# Epoch   9 Batch  425/538 - Train Accuracy:  0.366, Validation Accuracy:  0.398, Loss:  5.492
# Epoch   9 Batch  426/538 - Train Accuracy:  0.349, Validation Accuracy:  0.395, Loss:  5.494
# Epoch   9 Batch  427/538 - Train Accuracy:  0.321, Validation Accuracy:  0.391, Loss:  5.495
# Epoch   9 Batch  428/538 - Train Accuracy:  0.347, Validation Accuracy:  0.385, Loss:  5.465
# Epoch   9 Batch  429/538 - Train Accuracy:  0.361, Validation Accuracy:  0.385, Loss:  5.484
# Epoch   9 Batch  430/538 - Train Accuracy:  0.310, Validation Accuracy:  0.387, Loss:  5.492
# Epoch   9 Batch  431/538 - Train Accuracy:  0.322, Validation Accuracy:  0.389, Loss:  5.460
# Epoch   9 Batch  432/538 - Train Accuracy:  0.377, Validation Accuracy:  0.384, Loss:  5.475
# Epoch   9 Batch  433/538 - Train Accuracy:  0.308, Validation Accuracy:  0.380, Loss:  5.473
# Epoch   9 Batch  434/538 - Train Accuracy:  0.305, Validation Accuracy:  0.382, Loss:  5.467
# Epoch   9 Batch  435/538 - Train Accuracy:  0.306, Validation Accuracy:  0.382, Loss:  5.459
# Epoch   9 Batch  436/538 - Train Accuracy:  0.319, Validation Accuracy:  0.383, Loss:  5.478
# Epoch   9 Batch  437/538 - Train Accuracy:  0.313, Validation Accuracy:  0.380, Loss:  5.470
# Epoch   9 Batch  438/538 - Train Accuracy:  0.334, Validation Accuracy:  0.387, Loss:  5.466
# Epoch   9 Batch  439/538 - Train Accuracy:  0.330, Validation Accuracy:  0.387, Loss:  5.463
# Epoch   9 Batch  440/538 - Train Accuracy:  0.311, Validation Accuracy:  0.383, Loss:  5.483
# Epoch   9 Batch  441/538 - Train Accuracy:  0.310, Validation Accuracy:  0.385, Loss:  5.465
# Epoch   9 Batch  442/538 - Train Accuracy:  0.364, Validation Accuracy:  0.374, Loss:  5.446
# Epoch   9 Batch  443/538 - Train Accuracy:  0.323, Validation Accuracy:  0.373, Loss:  5.461
# Epoch   9 Batch  444/538 - Train Accuracy:  0.349, Validation Accuracy:  0.372, Loss:  5.444
# Epoch   9 Batch  445/538 - Train Accuracy:  0.310, Validation Accuracy:  0.390, Loss:  5.474
# Epoch   9 Batch  446/538 - Train Accuracy:  0.374, Validation Accuracy:  0.398, Loss:  5.458
# Epoch   9 Batch  447/538 - Train Accuracy:  0.331, Validation Accuracy:  0.400, Loss:  5.506
# Epoch   9 Batch  448/538 - Train Accuracy:  0.374, Validation Accuracy:  0.402, Loss:  5.478
# Epoch   9 Batch  449/538 - Train Accuracy:  0.327, Validation Accuracy:  0.400, Loss:  5.451
# Epoch   9 Batch  450/538 - Train Accuracy:  0.369, Validation Accuracy:  0.402, Loss:  5.449
# Epoch   9 Batch  451/538 - Train Accuracy:  0.339, Validation Accuracy:  0.398, Loss:  5.448
# Epoch   9 Batch  452/538 - Train Accuracy:  0.327, Validation Accuracy:  0.394, Loss:  5.491
# Epoch   9 Batch  453/538 - Train Accuracy:  0.315, Validation Accuracy:  0.382, Loss:  5.481
# Epoch   9 Batch  454/538 - Train Accuracy:  0.341, Validation Accuracy:  0.373, Loss:  5.468
# Epoch   9 Batch  455/538 - Train Accuracy:  0.380, Validation Accuracy:  0.369, Loss:  5.506
# Epoch   9 Batch  456/538 - Train Accuracy:  0.421, Validation Accuracy:  0.372, Loss:  5.443
# Epoch   9 Batch  457/538 - Train Accuracy:  0.310, Validation Accuracy:  0.373, Loss:  5.491
# Epoch   9 Batch  458/538 - Train Accuracy:  0.329, Validation Accuracy:  0.371, Loss:  5.457
# Epoch   9 Batch  459/538 - Train Accuracy:  0.303, Validation Accuracy:  0.370, Loss:  5.423
# Epoch   9 Batch  460/538 - Train Accuracy:  0.339, Validation Accuracy:  0.366, Loss:  5.468
# Epoch   9 Batch  461/538 - Train Accuracy:  0.249, Validation Accuracy:  0.371, Loss:  5.508
# Epoch   9 Batch  462/538 - Train Accuracy:  0.326, Validation Accuracy:  0.370, Loss:  5.463
# Epoch   9 Batch  463/538 - Train Accuracy:  0.309, Validation Accuracy:  0.369, Loss:  5.498
# Epoch   9 Batch  464/538 - Train Accuracy:  0.302, Validation Accuracy:  0.373, Loss:  5.506
# Epoch   9 Batch  465/538 - Train Accuracy:  0.297, Validation Accuracy:  0.373, Loss:  5.467
# Epoch   9 Batch  466/538 - Train Accuracy:  0.274, Validation Accuracy:  0.378, Loss:  5.504
# Epoch   9 Batch  467/538 - Train Accuracy:  0.331, Validation Accuracy:  0.376, Loss:  5.431
# Epoch   9 Batch  468/538 - Train Accuracy:  0.329, Validation Accuracy:  0.379, Loss:  5.480
# Epoch   9 Batch  469/538 - Train Accuracy:  0.322, Validation Accuracy:  0.383, Loss:  5.477
# Epoch   9 Batch  470/538 - Train Accuracy:  0.335, Validation Accuracy:  0.386, Loss:  5.480
# Epoch   9 Batch  471/538 - Train Accuracy:  0.331, Validation Accuracy:  0.383, Loss:  5.488
# Epoch   9 Batch  472/538 - Train Accuracy:  0.341, Validation Accuracy:  0.385, Loss:  5.465
# Epoch   9 Batch  473/538 - Train Accuracy:  0.312, Validation Accuracy:  0.385, Loss:  5.461
# Epoch   9 Batch  474/538 - Train Accuracy:  0.360, Validation Accuracy:  0.385, Loss:  5.471
# Epoch   9 Batch  475/538 - Train Accuracy:  0.375, Validation Accuracy:  0.391, Loss:  5.441
# Epoch   9 Batch  476/538 - Train Accuracy:  0.320, Validation Accuracy:  0.392, Loss:  5.465
# Epoch   9 Batch  477/538 - Train Accuracy:  0.336, Validation Accuracy:  0.386, Loss:  5.484
# Epoch   9 Batch  478/538 - Train Accuracy:  0.340, Validation Accuracy:  0.390, Loss:  5.476
# Epoch   9 Batch  479/538 - Train Accuracy:  0.351, Validation Accuracy:  0.388, Loss:  5.470
# Epoch   9 Batch  480/538 - Train Accuracy:  0.347, Validation Accuracy:  0.382, Loss:  5.471
# Epoch   9 Batch  481/538 - Train Accuracy:  0.349, Validation Accuracy:  0.383, Loss:  5.502
# Epoch   9 Batch  482/538 - Train Accuracy:  0.394, Validation Accuracy:  0.383, Loss:  5.445
# Epoch   9 Batch  483/538 - Train Accuracy:  0.338, Validation Accuracy:  0.383, Loss:  5.441
# Epoch   9 Batch  484/538 - Train Accuracy:  0.356, Validation Accuracy:  0.382, Loss:  5.448
# Epoch   9 Batch  485/538 - Train Accuracy:  0.347, Validation Accuracy:  0.385, Loss:  5.481
# Epoch   9 Batch  486/538 - Train Accuracy:  0.316, Validation Accuracy:  0.384, Loss:  5.469
# Epoch   9 Batch  487/538 - Train Accuracy:  0.346, Validation Accuracy:  0.383, Loss:  5.504
# Epoch   9 Batch  488/538 - Train Accuracy:  0.332, Validation Accuracy:  0.378, Loss:  5.446
# Epoch   9 Batch  489/538 - Train Accuracy:  0.310, Validation Accuracy:  0.383, Loss:  5.469
# Epoch   9 Batch  490/538 - Train Accuracy:  0.334, Validation Accuracy:  0.381, Loss:  5.441
# Epoch   9 Batch  491/538 - Train Accuracy:  0.289, Validation Accuracy:  0.379, Loss:  5.453
# Epoch   9 Batch  492/538 - Train Accuracy:  0.318, Validation Accuracy:  0.385, Loss:  5.468
# Epoch   9 Batch  493/538 - Train Accuracy:  0.354, Validation Accuracy:  0.389, Loss:  5.468
# Epoch   9 Batch  494/538 - Train Accuracy:  0.358, Validation Accuracy:  0.403, Loss:  5.460
# Epoch   9 Batch  495/538 - Train Accuracy:  0.341, Validation Accuracy:  0.408, Loss:  5.510
# Epoch   9 Batch  496/538 - Train Accuracy:  0.342, Validation Accuracy:  0.407, Loss:  5.465
# Epoch   9 Batch  497/538 - Train Accuracy:  0.362, Validation Accuracy:  0.403, Loss:  5.470
# Epoch   9 Batch  498/538 - Train Accuracy:  0.321, Validation Accuracy:  0.402, Loss:  5.458
# Epoch   9 Batch  499/538 - Train Accuracy:  0.366, Validation Accuracy:  0.404, Loss:  5.451
# Epoch   9 Batch  500/538 - Train Accuracy:  0.387, Validation Accuracy:  0.400, Loss:  5.459
# Epoch   9 Batch  501/538 - Train Accuracy:  0.369, Validation Accuracy:  0.398, Loss:  5.459
# Epoch   9 Batch  502/538 - Train Accuracy:  0.333, Validation Accuracy:  0.397, Loss:  5.473
# Epoch   9 Batch  503/538 - Train Accuracy:  0.372, Validation Accuracy:  0.396, Loss:  5.466
# Epoch   9 Batch  504/538 - Train Accuracy:  0.335, Validation Accuracy:  0.397, Loss:  5.462
# Epoch   9 Batch  505/538 - Train Accuracy:  0.345, Validation Accuracy:  0.400, Loss:  5.457
# Epoch   9 Batch  506/538 - Train Accuracy:  0.345, Validation Accuracy:  0.397, Loss:  5.472
# Epoch   9 Batch  507/538 - Train Accuracy:  0.340, Validation Accuracy:  0.388, Loss:  5.466
# Epoch   9 Batch  508/538 - Train Accuracy:  0.366, Validation Accuracy:  0.385, Loss:  5.473
# Epoch   9 Batch  509/538 - Train Accuracy:  0.321, Validation Accuracy:  0.385, Loss:  5.458
# Epoch   9 Batch  510/538 - Train Accuracy:  0.346, Validation Accuracy:  0.382, Loss:  5.463
# Epoch   9 Batch  511/538 - Train Accuracy:  0.381, Validation Accuracy:  0.380, Loss:  5.464
# Epoch   9 Batch  512/538 - Train Accuracy:  0.357, Validation Accuracy:  0.376, Loss:  5.485
# Epoch   9 Batch  513/538 - Train Accuracy:  0.318, Validation Accuracy:  0.376, Loss:  5.428
# Epoch   9 Batch  514/538 - Train Accuracy:  0.312, Validation Accuracy:  0.377, Loss:  5.484
# Epoch   9 Batch  515/538 - Train Accuracy:  0.345, Validation Accuracy:  0.378, Loss:  5.472
# Epoch   9 Batch  516/538 - Train Accuracy:  0.336, Validation Accuracy:  0.375, Loss:  5.419
# Epoch   9 Batch  517/538 - Train Accuracy:  0.353, Validation Accuracy:  0.371, Loss:  5.486
# Epoch   9 Batch  518/538 - Train Accuracy:  0.307, Validation Accuracy:  0.367, Loss:  5.467
# Epoch   9 Batch  519/538 - Train Accuracy:  0.360, Validation Accuracy:  0.370, Loss:  5.448
# Epoch   9 Batch  520/538 - Train Accuracy:  0.305, Validation Accuracy:  0.374, Loss:  5.471
# Epoch   9 Batch  521/538 - Train Accuracy:  0.353, Validation Accuracy:  0.382, Loss:  5.496
# Epoch   9 Batch  522/538 - Train Accuracy:  0.312, Validation Accuracy:  0.389, Loss:  5.476
# Epoch   9 Batch  523/538 - Train Accuracy:  0.297, Validation Accuracy:  0.394, Loss:  5.463
# Epoch   9 Batch  524/538 - Train Accuracy:  0.292, Validation Accuracy:  0.390, Loss:  5.522
# Epoch   9 Batch  525/538 - Train Accuracy:  0.356, Validation Accuracy:  0.393, Loss:  5.472
# Epoch   9 Batch  526/538 - Train Accuracy:  0.354, Validation Accuracy:  0.390, Loss:  5.457
# Epoch   9 Batch  527/538 - Train Accuracy:  0.315, Validation Accuracy:  0.382, Loss:  5.462
# Epoch   9 Batch  528/538 - Train Accuracy:  0.284, Validation Accuracy:  0.382, Loss:  5.480
# Epoch   9 Batch  529/538 - Train Accuracy:  0.319, Validation Accuracy:  0.377, Loss:  5.486
# Epoch   9 Batch  530/538 - Train Accuracy:  0.322, Validation Accuracy:  0.375, Loss:  5.466
# Epoch   9 Batch  531/538 - Train Accuracy:  0.308, Validation Accuracy:  0.381, Loss:  5.486
# Epoch   9 Batch  532/538 - Train Accuracy:  0.316, Validation Accuracy:  0.390, Loss:  5.485
# Epoch   9 Batch  533/538 - Train Accuracy:  0.338, Validation Accuracy:  0.398, Loss:  5.484
# Epoch   9 Batch  534/538 - Train Accuracy:  0.356, Validation Accuracy:  0.399, Loss:  5.458
# Epoch   9 Batch  535/538 - Train Accuracy:  0.343, Validation Accuracy:  0.397, Loss:  5.438
# Epoch   9 Batch  536/538 - Train Accuracy:  0.376, Validation Accuracy:  0.396, Loss:  5.477
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d7dd20c512f1> in <module>()
#      59     # Save Model
#      60     saver = tf.train.Saver()
# ---> 61     saver.save(sess, save_path)
#      62     print('Model Trained and Saved')
#
# C:\ProgramData\Anaconda3\envs\dlndpy35\lib\site-packages\tensorflow\python\training\saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1363     if not gfile.IsDirectory(os.path.dirname(save_path)):
#    1364       raise ValueError(
# -> 1365           "Parent directory of {} doesn't exist, can't save.".format(save_path))
#    1366
#    1367     save_path = os.path.dirname(save_path)
#
# ValueError: Parent directory of checkpoints/dev doesn't exist, can't save.

# %% [markdown]
# ### 保存参数
#
# 保存 `batch_size` 和 `save_path` 参数以进行推论（for inference）。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # 检查点

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## 句子到序列
#
# 要向模型提供要翻译的句子，你首先需要预处理该句子。实现函数 `sentence_to_seq()` 以预处理新的句子。
#
# - 将句子转换为小写形式
# - 使用 `vocab_to_int` 将单词转换为 id
#  - 如果单词不在词汇表中，将其转换为`<UNK>` 单词 id

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)

# %% [markdown]
# ## 翻译
#
# 将 `translate_sentence` 从英语翻译成法语。

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))

# %% [markdown]
# ## 不完美的翻译
#
# 你可能注意到了，某些句子的翻译质量比其他的要好。因为你使用的数据集只有 227 个英语单词，但实际生活中有数千个单词，只有使用这些单词的句子结果才会比较理想。对于此项目，不需要达到完美的翻译。但是，如果你想创建更好的翻译模型，则需要更好的数据。
#
# 你可以使用 [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar) 语料库训练模型。该数据集拥有更多的词汇，讨论的话题也更丰富。但是，训练时间要好多天的时间，所以确保你有 GPU 并且对于我们提供的数据集，你的神经网络性能很棒。提交此项目后，别忘了研究下 WMT10 语料库。
#
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。保存记事本文件为 “dlnd_language_translation.ipynb”，再通过菜单中的“文件” ->“下载为”将其另存为 HTML 格式。提交的项目文档中需包含“helper.py”和“problem_unittests.py”文件。
